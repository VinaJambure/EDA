# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('placementdata.csv')

# %%
df
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0             1   7.5            1         1                         1
# 1             2   8.9            0         3                         2
# 2             3   7.3            1         2                         2
# 3             4   7.5            1         1                         2
# 4             5   8.3            1         2                         2
# ...         ...   ...          ...       ...                       ...
# 9995       9996   7.5            1         1                         2
# 9996       9997   7.4            0         1                         0
# 9997       9998   8.4            1         3                         0
# 9998       9999   8.9            0         3                         2
# 9999      10000   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# ...

# %%
df.head()
# Out:
#    StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0          1   7.5            1         1                         1
# 1          2   8.9            0         3                         2
# 2          3   7.3            1         2                         2
# 3          4   7.5            1         1                         2
# 4          5   8.3            1         2                         2
#
#    AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 0                 65               4.4                        No
# 1                 90               4.0                       Yes
# 2                 82               4.8                       Yes
# 3                 85               4.4                       Yes
# 4                 86               4.5                       Yes
#
#   PlacementTraining  SSC_Marks  HSC_Marks PlacementStatus
# 0                No         61         79       NotPlaced
# ...

# %%
df.columns
# Out:
# Index(['StudentID', 'CGPA', 'Internships', 'Projects',
#        'Workshops/Certifications', 'AptitudeTestScore', 'SoftSkillsRating',
#        'ExtracurricularActivities', 'PlacementTraining', 'SSC_Marks',
#        'HSC_Marks', 'PlacementStatus'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10000 non-null  int64
#  1   CGPA                       10000 non-null  float64
#  2   Internships                10000 non-null  int64
#  3   Projects                   10000 non-null  int64
#  4   Workshops/Certifications   10000 non-null  int64
#  5   AptitudeTestScore          10000 non-null  int64
#  6   SoftSkillsRating           10000 non-null  float64
#  7   ExtracurricularActivities  10000 non-null  object
#  8   PlacementTraining          10000 non-null  object
#  9   SSC_Marks                  10000 non-null  int64
#  10  HSC_Marks                  10000 non-null  int64
#  11  PlacementStatus            10000 non-null  object
# dtypes: float64(2), int64(7), object(3)
# memory usage: 937.6+ KB

# %%
df.describe()
# Out:
#          StudentID          CGPA   Internships      Projects  \
# count  10000.00000  10000.000000  10000.000000  10000.000000
# mean    5000.50000      7.698010      1.049200      2.026600
# std     2886.89568      0.640131      0.665901      0.867968
# min        1.00000      6.500000      0.000000      0.000000
# 25%     2500.75000      7.400000      1.000000      1.000000
# 50%     5000.50000      7.700000      1.000000      2.000000
# 75%     7500.25000      8.200000      1.000000      3.000000
# max    10000.00000      9.100000      2.000000      3.000000
#
#        Workshops/Certifications  AptitudeTestScore  SoftSkillsRating  \
# count              10000.000000       10000.000000      10000.000000
# mean                   1.013200          79.449900          4.323960
# std                    0.904272           8.159997          0.411622
# min                    0.000000          60.000000          3.000000
# ...

# %%
plt.figure(figsize=(9,3))
plt.scatter(df['StudentID'],df['CGPA'])
plt.xlabel('CGPA')
plt.ylabel('StudentID')
plt.show()

# %%
df.columns
# Out:
# Index(['StudentID', 'CGPA', 'Internships', 'Projects',
#        'Workshops/Certifications', 'AptitudeTestScore', 'SoftSkillsRating',
#        'ExtracurricularActivities', 'PlacementTraining', 'SSC_Marks',
#        'HSC_Marks', 'PlacementStatus'],
#       dtype='object')

# %%
def bar_plot(variable):
    var = df[variable] 
    varValue = var.value_counts()  
    plt.figure(figsize=(5,3))
    plt.bar(varValue.index.astype(str), varValue)  
    plt.xticks(rotation=45)  
    plt.ylabel('StudentID')
    plt.xlabel(variable)
    plt.title(f'Distribution of {variable}')
    plt.show()

# %%
columns_plot = ['Workshops/Certifications', 'AptitudeTestScore', 'SoftSkillsRating'] 
for i in columns_plot:
    bar_plot(i)

# %%
plt.hist(df['CGPA'])
plt.show()

# %%
plt.hist(df['AptitudeTestScore'])
plt.show()

# %%
df.columns
# Out:
# Index(['StudentID', 'CGPA', 'Internships', 'Projects',
#        'Workshops/Certifications', 'AptitudeTestScore', 'SoftSkillsRating',
#        'ExtracurricularActivities', 'PlacementTraining', 'SSC_Marks',
#        'HSC_Marks', 'PlacementStatus'],
#       dtype='object')

# %%
plt.hist(df['SoftSkillsRating'])
plt.show()

# %%
plt.hist(df['SSC_Marks'])
plt.show()

# %%
plt.hist(df['HSC_Marks'])
plt.show()

# %%
import matplotlib.pyplot as plt

def hist_plot(vari):
    var = df[vari]  
    plt.figure(figsize=(9,3))
    plt.hist(var, bins=10, edgecolor='black', alpha=0.7)  
    plt.xlabel(vari)
    plt.ylabel('Frequency')
    plt.title(f'Histogram of {vari}')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()
    print(f'{vari}:\n{var.describe()}')

# %%
numeric_columns = ['CGPA', 'Internships', 'Projects', 'AptitudeTestScore', 'SoftSkillsRating', 'SSC_Marks', 'HSC_Marks']
for col in numeric_columns:
    hist_plot(col)
# Out:
# CGPA:
# count    10000.000000
# mean         7.698010
# std          0.640131
# min          6.500000
# 25%          7.400000
# 50%          7.700000
# 75%          8.200000
# max          9.100000
# Name: CGPA, dtype: float64
# Internships:
# count    10000.000000
# mean         1.049200
# std          0.665901
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          2.000000
# Name: Internships, dtype: float64
# Projects:
# count    10000.000000
# mean         2.026600
# std          0.867968
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          3.000000
# Name: Projects, dtype: float64
# AptitudeTestScore:
# count    10000.000000
# mean        79.449900
# std          8.159997
# min         60.000000
# 25%         73.000000
# 50%         80.000000
# 75%         87.000000
# max         90.000000
# Name: AptitudeTestScore, dtype: float64
# SoftSkillsRating:
# ...

# %%
def box_plot(vari, df):
    plt.figure(figsize=(9, 4))
    sns.boxplot(y=df[vari])
    plt.title(f'Box Plot of {vari}')
    plt.ylabel(vari)
    plt.show()

# %%
colum_plot=['CGPA', 'Internships', 'Projects', 'Workshops/Certifications','AptitudeTestScore', 'SoftSkillsRating',]
for i in colum_plot:
    if df[i].dtype in ['int64', 'float64']:  
        box_plot(i, df)

# %%
df.columns
# Out:
# Index(['StudentID', 'CGPA', 'Internships', 'Projects',
#        'Workshops/Certifications', 'AptitudeTestScore', 'SoftSkillsRating',
#        'ExtracurricularActivities', 'PlacementTraining', 'SSC_Marks',
#        'HSC_Marks', 'PlacementStatus'],
#       dtype='object')

# %%
sns.boxplot(df['SoftSkillsRating'])
# Out:
# <Axes: ylabel='SoftSkillsRating'>

# %%
df['Workshops/Certifications']=df['Workshops/Certifications'].fillna(df['Workshops/Certifications'].median())

# %%
df.isnull().sum()
# Out:
# StudentID                    0
# CGPA                         0
# Internships                  0
# Projects                     0
# Workshops/Certifications     0
# AptitudeTestScore            0
# SoftSkillsRating             0
# ExtracurricularActivities    0
# PlacementTraining            0
# SSC_Marks                    0
# HSC_Marks                    0
# PlacementStatus              0
# dtype: int64

# %%
df['SoftSkillsRating'].mode()
# Out:
# 0     1.228772
# 1     1.282863
# 2     1.692819
# 3     1.971023
# 4     3.059183
# 5     3.243630
# 6     3.607763
# 7     3.829204
# 8     4.693446
# 9     4.847869
# 10    5.444160
# 11    5.577136
# 12    5.704595
# 13    6.051495
# 14    6.727694
# 15    7.419203
# 16    7.799960
# 17    7.847065
# 18    7.938705
# 19    9.168098
# Name: SoftSkillsRating, dtype: float64

# %%
df['SoftSkillsRating']=df['SoftSkillsRating'].fillna(df['SoftSkillsRating'].mode()[0])

# %%
df.isna().sum()
# Out:
# StudentID                    0
# CGPA                         0
# Internships                  0
# Projects                     0
# Workshops/Certifications     0
# AptitudeTestScore            0
# SoftSkillsRating             0
# ExtracurricularActivities    0
# PlacementTraining            0
# SSC_Marks                    0
# HSC_Marks                    0
# PlacementStatus              0
# dtype: int64

# %%
df.drop(labels=['ExtracurricularActivities','PlacementTraining','SSC_Marks','HSC_Marks','PlacementStatus'],axis=1)
# Out:
#     StudentID      CGPA  Internships  Projects  Workshops/Certifications  \
# 0           1  6.872701            2         2                         1
# 1           2  9.753572            1         5                         9
# 2           3  8.659970            3         2                         3
# 3           4  7.993292            3         4                         7
# 4           5  5.780093            2         4                         6
# 5           6  5.779973            3         4                         8
# 6           7  5.290418            3         4                         7
# 7           8  9.330881            0         5                         4
# 8           9  8.005575            2         3                         1
# 9          10  8.540363            4         1                         4
# 10         11  5.102922            2         4                         7
# 11         12  9.849549            4         2                         9
# ...

# %%
df.columns
# Out:
# Index(['StudentID', 'CGPA', 'Internships', 'Projects',
#        'Workshops/Certifications', 'AptitudeTestScore', 'SoftSkillsRating',
#        'ExtracurricularActivities', 'PlacementTraining', 'SSC_Marks',
#        'HSC_Marks', 'PlacementStatus'],
#       dtype='object')

# %%
df.head()
# Out:
#    StudentID      CGPA  Internships  Projects  Workshops/Certifications  \
# 0          1  6.872701            2         2                         1
# 1          2  9.753572            1         5                         9
# 2          3  8.659970            3         2                         3
# 3          4  7.993292            3         4                         7
# 4          5  5.780093            2         4                         6
#
#    AptitudeTestScore  SoftSkillsRating  ExtracurricularActivities  \
# 0          43.910098          7.419203                          3
# 1          30.386548          7.847065                          1
# 2          87.082300          6.051495                          1
# 3          79.480014          7.938705                          4
# 4          81.030502          5.444160                          0
#
#    PlacementTraining  SSC_Marks  HSC_Marks  PlacementStatus
# 0                  1  75.939531  83.606777                0
# ...

# %%
df.drop(labels=['ExtracurricularActivities','PlacementTraining','SSC_Marks','HSC_Marks','PlacementStatus'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    StudentID      CGPA  Internships  Projects  Workshops/Certifications  \
# 0          1  6.872701            2         2                         1
# 1          2  9.753572            1         5                         9
# 2          3  8.659970            3         2                         3
# 3          4  7.993292            3         4                         7
# 4          5  5.780093            2         4                         6
#
#    AptitudeTestScore  SoftSkillsRating
# 0          43.910098          7.419203
# 1          30.386548          7.847065
# 2          87.082300          6.051495
# 3          79.480014          7.938705
# 4          81.030502          5.444160

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   StudentID                 20 non-null     int64
#  1   CGPA                      20 non-null     float64
#  2   Internships               20 non-null     int32
#  3   Projects                  20 non-null     int32
#  4   Workshops/Certifications  20 non-null     int32
#  5   AptitudeTestScore         20 non-null     float64
#  6   SoftSkillsRating          20 non-null     float64
# dtypes: float64(3), int32(3), int64(1)
# memory usage: 1012.0 bytes

# %%
sns.heatmap(df.corr(),annot=True,fmt='.2f')
plt.show()
